# %%
import pandas as pd
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xlrd

# %%
def convert_sheetdata(fname,sh):
    d = pd.read_excel(fname,sheet_name=sh)
    got_it = 0
    ends = []
    for i in d.index:
        if d.loc[i,'Unnamed: 8'] == 'TOTAL':
            got_it += 1
            ends.append(i)
            if got_it == 2:
                break
    starts = [3,ends[0]+4]
    d_new = pd.concat([d.loc[starts[0]:ends[0]-1,:],d.loc[starts[1]:ends[1]-1,:]])
    d_new.reset_index(inplace=True)
    d_new.drop('index',inplace=True,axis=1)
    odd = d_new.loc[[i for i in d_new.index if i%2==1],['Unnamed: '+str(i) for i in range(5,9)]+['Unnamed: 10']]
    odd.reset_index(inplace=True)
    odd.drop('index',inplace=True,axis=1)
    odd.columns = [i+'_unloading' for i in odd.columns]
    d_new.drop([i for i in d_new.index if i%2==1],inplace=True,axis=0)
    d_new.reset_index(inplace=True)
    d_new.drop('index',inplace=True,axis=1)
    d_new.head(100)
    new_data = pd.concat([d_new,odd],axis=1)
    new_data.drop(['Unnamed: 4','Unnamed: 10'],axis=1,inplace=True)
    cols = ['Line','Client','Placement Time','Destination','JNPT loading','GTI loading','NSICT loading','BMCT loading','Total loading','Completion Time','Removal Time','Loading dtn','Removal dtn','JNPT unloading','GTI unloading','NSICT unloading','BMCT unloading','Total unloading']
    new_data.columns = cols
    new_data = new_data[['Line','Client','Destination','Placement Time','Completion Time','Removal Time','Loading dtn','Removal dtn','JNPT loading','GTI loading','NSICT loading','BMCT loading','Total loading','JNPT unloading','GTI unloading','NSICT unloading','BMCT unloading','Total unloading']]
    new_data['Loading dtn'] = new_data['Completion Time']-new_data['Placement Time']
    new_data['Removal dtn'] = new_data['Removal Time']-new_data['Completion Time']
    new_data['Loading dtn'] = new_data['Loading dtn'].apply(lambda x: x.seconds/3600)
    new_data['Removal dtn'] = new_data['Removal Time'].apply(lambda x: x.seconds/3600)
    return new_data

# %%
def

# %%
xls = xlrd.open_workbook(r'data/JAN=2022.xlsx', on_demand=True)
jan_sheet_names = xls.sheet_names()
d = convert_sheetdata('data/JAN=2022.xlsx',jan_sheet_names[10])
d.head(100)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\AnacondaInstallation\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Loading Time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-110-9c1a8a77d56e> in <module>
#       1 xls = xlrd.open_workbook(r'data/JAN=2022.xlsx', on_demand=True)
#       2 jan_sheet_names = xls.sheet_names()
# ----> 3 d = convert_sheetdata('data/JAN=2022.xlsx',jan_sheet_names[10])
#       4 d.head(100)
#
# <ipython-input-109-740c31d9a337> in convert_sheetdata(fname, sh)
#      28     new_data['Loading dtn'] = new_data['Completion Time']-new_data['Placement Time']
#      29     new_data['Removal dtn'] = new_data['Removal Time']-new_data['Completion Time']
# ---> 30     new_data['Loading Time'] = new_data['Loading Time'].apply(lambda x: x.seconds/3600)
#      31     new_data['Removal Time'] = new_data['Removal Time'].apply(lambda x: x.seconds/3600)
#      32     return new_data
#
# D:\AnacondaInstallation\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# D:\AnacondaInstallation\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Loading Time'

# %%
(d.loc[1,'Completion Time']-d.loc[1,'Placement Time']).seconds/3600
# Out:
# 7.166666666666667

# %%
(d.loc[1,'Removal Time']-d.loc[1,'Completion Time']).seconds/3600
# Out:
# 1.0

# %%
d['Loading dtn'] = (d['Completion Time']-d['Placement Time'])
d.head(100)
# Out:
#    Line  Client Destination       Placement Time      Completion Time  \
# 0    B3    CONR        DRTA  2022-01-09 15:20:00  2022-01-10 04:30:00
# 1     4    CONR        PCPK  2022-01-09 21:50:00  2022-01-10 05:00:00
# 2     6    CONR        DRTA  2022-01-09 22:30:00  2022-01-10 08:30:00
# 3     1    CONR        PCPK  2022-01-09 23:55:00  2022-01-10 07:30:00
# 4     8    CONR         TKD  2022-01-10 02:20:00  2022-01-10 14:45:00
# 5    G3    CONR         DLB  2022-01-10 02:55:00  2022-01-10 12:00:00
# 6     5    CONR        CGPT  2022-01-10 03:55:00  2022-01-10 09:10:00
# 7     4    CONR         SNF  2022-01-10 06:55:00  2022-01-10 18:30:00
# 8    G2    CONR        PCPK  2022-01-10 07:00:00  2022-01-10 17:30:00
# 9    G1    CONR        MDDP  2022-01-10 08:00:00  2022-01-10 23:00:00
# 10    1    CONR        KHDB  2022-01-10 11:50:00  2022-01-10 23:30:00
# 11   G3    CONR        BNGD  2022-01-10 14:10:00  2022-01-10 23:45:00
# 12   G1  DLI 13        DLIB  2022-01-09 19:40:00  2022-01-10 03:50:00
# 13   B4  NCP 15        NTSJ  2022-01-09 23:15:00  2022-01-10 12:50:00
# 14   B2  PMLP09        MKPP  2022-01-10 03:30:00  2022-01-10 15:45:00
# 15    5   DLI14        DLIB  2022-01-10 11:05:00  2022-01-10 20:00:00
# 16   B3  ADIL28        NTSJ  2022-01-10 06:35:00  2022-01-10 21:20:00
# 17    6   NCP16        NTSJ  2022-01-10 10:40:00  2022-01-10 23:40:00
# 18   B1  GRPL06        GRFV  2022-01-10 18:45:00  2022-01-10 23:50:00
#
#            Removal Time     Loading dtn Removal dtn JNPT loading GTI loading  \
# 0   2022-01-10 05:25:00 0 days 13:10:00    00:55:00            0           0
# 1   2022-01-10 06:00:00 0 days 07:10:00    01:00:00            0           0
# 2   2022-01-10 09:20:00 0 days 10:00:00    00:50:00            0           4
# 3   2022-01-10 08:55:00 0 days 07:35:00    01:25:00           23          17
# 4   2022-01-10 15:35:00 0 days 12:25:00    00:50:00            5          43
# 5   2022-01-10 13:00:00 0 days 09:05:00    01:00:00            5          70
# 6   2022-01-10 10:00:00 0 days 05:15:00    00:50:00            0           0
# 7   2022-01-10 20:05:00 0 days 11:35:00    01:35:00            0           0
# 8   2022-01-10 18:35:00 0 days 10:30:00    01:05:00            0          60
# 9   2022-01-10 23:55:00 0 days 15:00:00    00:55:00            0          26
# 10  2022-01-11 00:30:00 0 days 11:40:00    01:00:00           90           0
# 11  2022-01-11 03:35:00 0 days 09:35:00    03:50:00            0          50
# 12  2022-01-10 04:50:00 0 days 08:10:00    01:00:00           20          70
# 13  2022-01-10 13:45:00 0 days 13:35:00    00:55:00            0           0
# 14  2022-01-10 17:00:00 0 days 12:15:00    01:15:00            0           2
# 15  2022-01-10 21:30:00 0 days 08:55:00    01:30:00            0           0
# 16  2022-01-10 22:00:00 0 days 14:45:00    00:40:00            0           0
# 17  2022-01-11 02:15:00 0 days 13:00:00    02:35:00           66          24
# 18  2022-01-11 04:30:00 0 days 05:05:00    04:40:00            0           0
#
#    NSICT loading BMCT loading Total loading JNPT unloading GTI unloading  \
# 0              0           90            90              0             0
# 1             90            0            90              0            36
# 2             86            0            90              0             2
# 3             20           30            90              0            15
# 4             37            5            90              0            28
# 5              6            9            90              0            20
# 6             90            0            90              7            15
# 7             90            0            90              0             4
# 8             30            0            90              0            28
# 9             48            4            78              0            43
# 10             0            0            90              2            42
# 11            40            0            90              0            20
# 12             0            0            90              0            83
# 13             0           90            90              0             4
# 14             0           88            90              1            36
# 15            90            0            90              0            18
# 16             0           88            88              0             0
# 17             0            0            90              0             0
# 18             0           90            90              0            45
#
#    NSICT unloading BMCT unloading Total unloading
# 0                0             90              90
# 1               51              3              90
# 2               69             19              90
# 3               57             18              90
# 4               56              6              90
# 5                0             70              90
# 6               60              8              90
# 7               28             58              90
# 8               47             15              90
# 9               17             30              90
# 10              16             30              90
# 11              47             23              90
# 12               0              7              90
# 13              46             40              90
# 14              18             25              80
# 15              70              2              90
# 16               0             90              90
# 17               0             90              90
# 18               3             42              90

# %%
d['Loading dtn'] = d['Loading dtn'].apply(lambda x: x.seconds/3600)
d.head(100)
# Out:
#    Line  Client Destination       Placement Time      Completion Time  \
# 0    B3    CONR        DRTA  2022-01-09 15:20:00  2022-01-10 04:30:00
# 1     4    CONR        PCPK  2022-01-09 21:50:00  2022-01-10 05:00:00
# 2     6    CONR        DRTA  2022-01-09 22:30:00  2022-01-10 08:30:00
# 3     1    CONR        PCPK  2022-01-09 23:55:00  2022-01-10 07:30:00
# 4     8    CONR         TKD  2022-01-10 02:20:00  2022-01-10 14:45:00
# 5    G3    CONR         DLB  2022-01-10 02:55:00  2022-01-10 12:00:00
# 6     5    CONR        CGPT  2022-01-10 03:55:00  2022-01-10 09:10:00
# 7     4    CONR         SNF  2022-01-10 06:55:00  2022-01-10 18:30:00
# 8    G2    CONR        PCPK  2022-01-10 07:00:00  2022-01-10 17:30:00
# 9    G1    CONR        MDDP  2022-01-10 08:00:00  2022-01-10 23:00:00
# 10    1    CONR        KHDB  2022-01-10 11:50:00  2022-01-10 23:30:00
# 11   G3    CONR        BNGD  2022-01-10 14:10:00  2022-01-10 23:45:00
# 12   G1  DLI 13        DLIB  2022-01-09 19:40:00  2022-01-10 03:50:00
# 13   B4  NCP 15        NTSJ  2022-01-09 23:15:00  2022-01-10 12:50:00
# 14   B2  PMLP09        MKPP  2022-01-10 03:30:00  2022-01-10 15:45:00
# 15    5   DLI14        DLIB  2022-01-10 11:05:00  2022-01-10 20:00:00
# 16   B3  ADIL28        NTSJ  2022-01-10 06:35:00  2022-01-10 21:20:00
# 17    6   NCP16        NTSJ  2022-01-10 10:40:00  2022-01-10 23:40:00
# 18   B1  GRPL06        GRFV  2022-01-10 18:45:00  2022-01-10 23:50:00
#
#            Removal Time  Loading dtn Removal dtn JNPT loading GTI loading  \
# 0   2022-01-10 05:25:00    13.166667    00:55:00            0           0
# 1   2022-01-10 06:00:00     7.166667    01:00:00            0           0
# 2   2022-01-10 09:20:00    10.000000    00:50:00            0           4
# 3   2022-01-10 08:55:00     7.583333    01:25:00           23          17
# 4   2022-01-10 15:35:00    12.416667    00:50:00            5          43
# 5   2022-01-10 13:00:00     9.083333    01:00:00            5          70
# 6   2022-01-10 10:00:00     5.250000    00:50:00            0           0
# 7   2022-01-10 20:05:00    11.583333    01:35:00            0           0
# 8   2022-01-10 18:35:00    10.500000    01:05:00            0          60
# 9   2022-01-10 23:55:00    15.000000    00:55:00            0          26
# 10  2022-01-11 00:30:00    11.666667    01:00:00           90           0
# 11  2022-01-11 03:35:00     9.583333    03:50:00            0          50
# 12  2022-01-10 04:50:00     8.166667    01:00:00           20          70
# 13  2022-01-10 13:45:00    13.583333    00:55:00            0           0
# 14  2022-01-10 17:00:00    12.250000    01:15:00            0           2
# 15  2022-01-10 21:30:00     8.916667    01:30:00            0           0
# 16  2022-01-10 22:00:00    14.750000    00:40:00            0           0
# 17  2022-01-11 02:15:00    13.000000    02:35:00           66          24
# 18  2022-01-11 04:30:00     5.083333    04:40:00            0           0
#
#    NSICT loading BMCT loading Total loading JNPT unloading GTI unloading  \
# 0              0           90            90              0             0
# 1             90            0            90              0            36
# 2             86            0            90              0             2
# 3             20           30            90              0            15
# 4             37            5            90              0            28
# 5              6            9            90              0            20
# 6             90            0            90              7            15
# 7             90            0            90              0             4
# 8             30            0            90              0            28
# 9             48            4            78              0            43
# 10             0            0            90              2            42
# 11            40            0            90              0            20
# 12             0            0            90              0            83
# 13             0           90            90              0             4
# 14             0           88            90              1            36
# 15            90            0            90              0            18
# 16             0           88            88              0             0
# 17             0            0            90              0             0
# 18             0           90            90              0            45
#
#    NSICT unloading BMCT unloading Total unloading
# 0                0             90              90
# 1               51              3              90
# 2               69             19              90
# 3               57             18              90
# 4               56              6              90
# 5                0             70              90
# 6               60              8              90
# 7               28             58              90
# 8               47             15              90
# 9               17             30              90
# 10              16             30              90
# 11              47             23              90
# 12               0              7              90
# 13              46             40              90
# 14              18             25              80
# 15              70              2              90
# 16               0             90              90
# 17               0             90              90
# 18               3             42              90
